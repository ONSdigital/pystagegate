# %% [markdown]
# # Pystagegate Demos
#
# Executable notebook demonstrating code usage

# %%
import os
from pystagegate.pipelines import prov_fin_main

os.chdir("..")

prov_fin_output = prov_fin_main("tests/data/testing_config.json")

# %%
prov_fin_output.head(10)

# %%
prov_fin_output.groupby("Nation")[["sqdiff_imm_sc", "imm_prov"]].corr()
